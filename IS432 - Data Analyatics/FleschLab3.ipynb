# %%
import pandas as pd
df = pd.read_csv("mammals.csv")
df.head()
# Out:
#                   species   body_wt  brain_wt  non_dreaming  dreaming  \
# 0         Africanelephant  6654.000    5712.0           NaN       NaN
# 1  Africangiantpouchedrat     1.000       6.6           6.3       2.0
# 2               ArcticFox     3.385      44.5           NaN       NaN
# 3    Arcticgroundsquirrel     0.920       5.7           NaN       NaN
# 4           Asianelephant  2547.000    4603.0           2.1       1.8
#
#    total_sleep  life_span  gestation  predation  exposure  danger
# 0          3.3       38.6      645.0          3         5       3
# 1          8.3        4.5       42.0          3         1       3
# 2         12.5       14.0       60.0          1         1       1
# 3         16.5        NaN       25.0          5         2       3
# 4          3.9       69.0      624.0          3         5       4

# %%
df.describe()
# Out:
#            body_wt     brain_wt  non_dreaming   dreaming  total_sleep  \
# count    62.000000    62.000000     48.000000  50.000000    58.000000
# mean    198.789984   283.134194      8.672917   1.972000    10.532759
# std     899.158011   930.278942      3.666452   1.442651     4.606760
# min       0.005000     0.140000      2.100000   0.000000     2.600000
# 25%       0.600000     4.250000      6.250000   0.900000     8.050000
# 50%       3.342500    17.250000      8.350000   1.800000    10.450000
# 75%      48.202500   166.000000     11.000000   2.550000    13.200000
# max    6654.000000  5712.000000     17.900000   6.600000    19.900000
#
#         life_span   gestation  predation   exposure     danger
# count   58.000000   58.000000  62.000000  62.000000  62.000000
# mean    19.877586  142.353448   2.870968   2.419355   2.612903
# std     18.206255  146.805039   1.476414   1.604792   1.441252
# min      2.000000   12.000000   1.000000   1.000000   1.000000
# ...

# %% [markdown]
# <h1> 2a) Which of the 10 attributes do you think the mean is the best measure of central tendency for? Why do you think this? <h1/>
# <h3>I don't believe that any of the 10 attribute's mean can be used to determine the central tendency for any species since each species is unique in terms of weight, dreaming/non-dreaming ability, sleep, and longevity. <h3/>
# <h1> 2b) Which of the 10 attributes do you think the median is the best measure of central tendency for?Why do you think this? <h1/>
# <h3> I believe the median is the best option for calculating exposure and risk since it takes the average of all the species data while excluding the highest values as outliers<h3/>
# <h1> 2c) Which attribute has the greatest variation in data? How do you know? <h1/>
# <h3>We can see that the attribute body weight has the greatest variation in data.  We know this because we use difference between the highest and lowest value is used to compute it. <h3/>
# <h1>2d) What is the range of the gestation length?How do you know?<h1/>
# <h3>The gestation length range is 633<h3/>
# <h1>2e) According to Chebychev’s rule, at least 89% of the observations for dreaming willlie between what two numbers?<h1/>
# <h3> In a range of three standard deviations around the mean, Chebyshev's Theorem states that at least 89% of the observations fall inside that range, and no more than 11% fall outside that range<h3/>
# <h1>2f) What is the interquartile range for body weight?<h1/>
# <h3>The interquartile range for body weight is 48.197<h3/>
# <h1>2g) Give an attribute where the maximum value is a potential outlier. How do you know<h1/>
# <h3> An attribute where the maximum value is a potential outlier is body weight, We know this because the maximum weight is 6654 pounds, with a mean of 198.7 pounds and a 75 percentile of 48.2. This clearly demonstrates that the maximum body weight figure is a possible outlier.<h3/>

# %%
df_dropped = df.dropna()

# %%
df_dropped.describe()
# Out:
#            body_wt     brain_wt  non_dreaming   dreaming  total_sleep  \
# count    42.000000    42.000000     42.000000  42.000000    42.000000
# mean    100.813905   218.683810      8.742857   1.900000    10.642857
# std     402.082389   732.848427      3.837437   1.388805     4.709417
# min       0.005000     0.140000      2.100000   0.000000     2.900000
# 25%       0.316250     3.600000      6.150000   0.900000     8.050000
# 50%       2.250000    12.200000      8.500000   1.650000     9.800000
# 75%      10.412500   155.500000     11.000000   2.375000    13.600000
# max    2547.000000  4603.000000     17.900000   6.600000    19.900000
#
#         life_span   gestation  predation   exposure     danger
# count   42.000000   42.000000  42.000000  42.000000  42.000000
# mean    19.371429  129.940476   2.952381   2.357143   2.690476
# std     20.257131  127.839848   1.447494   1.527335   1.387894
# min      2.000000   12.000000   1.000000   1.000000   1.000000
# ...

# %% [markdown]
# <h1>4a) Identify three attributes that had values that changed.  How did they change (get smaller or bigger)?<h1/>
# <h3>Count, mean, and standard deviation are the three attributes whose values have altered. All of these three attributes' values shrank and bacame smaller. <h3/>
# <h1>4b) Was there any row that remained unchanged for all attributes?  If so, why do youthink that is? <h1/>
# <h3>Yes, the row that remained unchanged for all attribute is min <h3/>
# <h1>4c) Would any of the changes in part (a) be misleading?Explain your answer.<h1/>
# <h3>I don't believe any of the adjustments were deceptive since it is self-evident that if a value is removed, the count, mean, and standard deviation would all decrease.
# <h3/>
# <h1>4d) What is an advantage of this method of cleaning the data? <h1/>
# <h3>The greatest benefit of this technique of data cleansing, I believe, is that it allows you to delete attribute values that have no meaning and may later become a problem. The removal of whole rows is more deceptive than incomplete data with a connection. It will just provide factual information. <h3/>
# <h1> 4e) What is the disadvantage of cleaning the data? <h1/>
# <h3> The main disadvantage of cleaning the data in this way is that other data in the same rows will be lost.<h3/>

# %%
column_means = df.mean()
df_mean = df.fillna(column_means)

# %%
df_mean.describe()
# Out:
#            body_wt     brain_wt  non_dreaming   dreaming  total_sleep  \
# count    62.000000    62.000000     62.000000  62.000000    62.000000
# mean    198.789984   283.134194      8.672917   1.972000    10.532759
# std     899.158011   930.278942      3.218326   1.292987     4.453158
# min       0.005000     0.140000      2.100000   0.000000     2.600000
# 25%       0.600000     4.250000      6.800000   1.050000     8.225000
# 50%       3.342500    17.250000      8.672917   1.972000    10.532759
# 75%      48.202500   166.000000     10.550000   2.275000    13.150000
# max    6654.000000  5712.000000     17.900000   6.600000    19.900000
#
#         life_span   gestation  predation   exposure     danger
# count   62.000000   62.000000  62.000000  62.000000  62.000000
# mean    19.877586  142.353448   2.870968   2.419355   2.612903
# std     17.599209  141.910154   1.476414   1.604792   1.441252
# min      2.000000   12.000000   1.000000   1.000000   1.000000
# ...

# %% [markdown]
# <h1>6a) Identify three attributes that had values that changed (from the original, not thedropped).  How did they change (get smaller or bigger)? <h1/>
# <h3>Count, mean, and standard deviation are the three attributes whose values have altered. The count decreased, but the mean and standard deviation increased.<h3/>
# <h1>6b) Was there any row that remained unchanged for all attributes?  If so, why do you think that is? <h1/>
# <h3>The minimum and maximum values are unaffected. Even if we replace the missing data with the mean, I believe the lowest and maximum values will remain the same.<h3/>
# <h1>6c) Would any of the changes in part (a) be misleading?Explain your answer.<h1/>
# <h3>The minimum and maximum values are unaffected. Even if we replace the missing data with the mean, I believe the lowest and maximum values will remain the same.<h3/>
# <h1>6d) What is an advantage of this method of cleaning the data<h1/>
# <h3>The primary benefit of this approach over removing the missing data rows is that the whole rows of data will not be destroyed. Other data would still be available, which might be useful in a variety of ways.<h3/>
# <h1>6e) What is the disadvantage of cleaning the data?<h1/>
# <h3>The main drawbacks, in my opinion, would be that substituting values with means would result in greater values than anticipated. For example, we received a 75 percentile that was much higher than anticipated, thus these data increments may sometimes cause difficulties and misunderstanding.<h3/>

# %%
boxplot = df.boxplot(column=['body_wt', 'brain_wt'])

# %% [markdown]
# <h1>8a) Did you get a good visualization of the data? Explain<h1/>
# <h3>No, I wasn't able to create a decent data visualization. I'm having trouble adequately cleifying the diagram. The data is poorly presented, and the diagrams for both body and brain weight are tiny, making it difficult to distinguish between Q1, Q3, and IQR.<h3/>
#  <h1>8b) Are there any outliers?How do you know?<h1/>
# <h3>There are a few outliers, to be sure. We can see in the figure above that a couple of the dots are distant from the maximum point of the boxplots, indicating that they are outliers.<h3/>

# %%
boxplot = df.boxplot(column=['non_dreaming', 'dreaming', 'total_sleep'])

# %% [markdown]
# <h1>10a) Did you get a good visualization of the data? Explain<h1/>
# <h3>Yes, I was able to see the data well. The picture is crisp, and I can easily identify the minimum/maximum value, Q1/Q3, median, and interquartile range, making this an informative and easy-to-understand boxplot.<h3/>
# <h1>10b) Are there any outliers?How do you know?<h1/>
# <h3>Only on the dreaming's boxplots can we notice some of the outliers that aren't close to the boxplot's maximum value.<h3/>
