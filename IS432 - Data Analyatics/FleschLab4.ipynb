# %%
import pandas as pd
df = pd.read_csv("bankfull.csv")
df
# Out:
#        age            job    marital              education    default  \
# 0       56     housemaid    married               basic.4y         no
# 1       57      services    married            high.school    unknown
# 2       37      services    married            high.school         no
# 3       40        admin.    married               basic.6y         no
# 4       56      services    married            high.school         no
# ...    ...            ...        ...                    ...        ...
# 41183   73       retired    married    professional.course         no
# 41184   46   blue-collar    married    professional.course         no
# 41185   56       retired    married      university.degree         no
# 41186   44    technician    married    professional.course         no
# 41187   74       retired    married    professional.course         no
#
#       housing   loan      contact  month day_of_week  ...  campaign  pdays  \
# ...

# %%
import matplotlib.pyplot as plt
df = pd.read_csv("bankfull.csv")
histo_d = df.hist(['pdays'], bins = 10)
plt.ylabel('Frequencies')
plt.xlabel('Last time a client called')
# Out:
# Text(0.5, 0, 'Last time a client called')

# %% [markdown]
# <h3> We can observe from this histogram that there is a significant difference between the number of days customers were last contacted, which is from day 1 to day 999, and that the days clients were last phoned was after 999 days which has a higher frequency than those called lately.<h3/>

# %%
import numpy as np
df['pdays']=df['pdays'].replace({999: np.NaN})
histo_d = df.hist(['pdays'], bins = 10)
plt.ylabel('Frequencies')
plt.xlabel('Last time a client called')
# Out:
# Text(0.5, 0, 'Last time a client called')

# %% [markdown]
# <h3> After creating another histogram, we can notice that the data is much closer compared to the old historagam. We can also see that there is a bigger number of customers who have not recently returned calls and can see the data that is relevant to the campaign on who called back, this data shows an cleaner histogram.<h3/>

# %%
df['education_numeric'] = df['education']
df
# Out:
#        age            job    marital              education    default  \
# 0       56     housemaid    married               basic.4y         no
# 1       57      services    married            high.school    unknown
# 2       37      services    married            high.school         no
# 3       40        admin.    married               basic.6y         no
# 4       56      services    married            high.school         no
# ...    ...            ...        ...                    ...        ...
# 41183   73       retired    married    professional.course         no
# 41184   46   blue-collar    married    professional.course         no
# 41185   56       retired    married      university.degree         no
# 41186   44    technician    married    professional.course         no
# 41187   74       retired    married    professional.course         no
#
#       housing   loan      contact  month day_of_week  ...  pdays  previous  \
# ...

# %%
dict_edu = {"education_numeric":{" illiterate ":0, " basic.4y ":4, " basic.6y ":6," basic.9y ":9,
                                 " high.school ":12, " professional.course ":12, " university.degree ":16,
                                 " unknown ":np.NaN}}

# %%
df.replace(dict_edu, inplace=True)
df
# Out:
#        age            job    marital              education    default  \
# 0       56     housemaid    married               basic.4y         no
# 1       57      services    married            high.school    unknown
# 2       37      services    married            high.school         no
# 3       40        admin.    married               basic.6y         no
# 4       56      services    married            high.school         no
# ...    ...            ...        ...                    ...        ...
# 41183   73       retired    married    professional.course         no
# 41184   46   blue-collar    married    professional.course         no
# 41185   56       retired    married      university.degree         no
# 41186   44    technician    married    professional.course         no
# 41187   74       retired    married    professional.course         no
#
#       housing   loan      contact  month day_of_week  ...  pdays  previous  \
# ...

# %%
df
# Out:
#        age            job    marital              education    default  \
# 0       56     housemaid    married               basic.4y         no
# 1       57      services    married            high.school    unknown
# 2       37      services    married            high.school         no
# 3       40        admin.    married               basic.6y         no
# 4       56      services    married            high.school         no
# ...    ...            ...        ...                    ...        ...
# 41183   73       retired    married    professional.course         no
# 41184   46   blue-collar    married    professional.course         no
# 41185   56       retired    married      university.degree         no
# 41186   44    technician    married    professional.course         no
# 41187   74       retired    married    professional.course         no
#
#       housing   loan      contact  month day_of_week  ...  pdays  previous  \
# ...

# %%
df['education_numeric'].hist()
plt.ylabel('Clients')
plt.xlabel('Education Level') 
plt.title('Education')
# Out:
# Text(0.5, 1.0, 'Education')

# %% [markdown]
# <h3>  After ploting histogram of the education level we notice that majority of clients has university level education followed by high school and  professional course, and so on. <h3/>

# %%
from scipy import stats
df['age_z']=stats.zscore(df['age'])

# %%
df['age_z'].hist()
plt.ylabel('Client')
plt.xlabel('Zscore') 
plt.title('Age')
# Out:
# Text(0.5, 1.0, 'Age')

# %% [markdown]
# <h3><h3/>

# %%
df_outliers = df.query('age_z > 3 | age_z < -3')

# %%
s_out = np.array([df_outliers])
print (np.shape(s_out))
# Out:
# (1, 369, 23)

# %% [markdown]
# <h3> a. It seems that there are 369 outliers. b. There are 41,188 rows in the original Dataset.
# c. Extracted from the original Dataset Outliers made up 9% of the group.
# d. The proportion of outliers in relation to Chebyshev's rule is the method by which we get there, but Chebyshev's rule takes the standard deviation from the mean and squares it, resulting in a considerably greater figure with the standard deviation.<h3/>

# %%
df_dummies = pd.get_dummies(df, columns=['marital'])
df_dummies.head(20)
# Out:
#     age            job              education    default housing   loan  \
# 0    56     housemaid               basic.4y         no      no     no
# 1    57      services            high.school    unknown      no     no
# 2    37      services            high.school         no     yes     no
# 3    40        admin.               basic.6y         no      no     no
# 4    56      services            high.school         no      no    yes
# 5    45      services               basic.9y    unknown      no     no
# 6    59        admin.    professional.course         no      no     no
# 7    41   blue-collar                unknown    unknown      no     no
# 8    24    technician    professional.course         no     yes     no
# 9    25      services            high.school         no     yes     no
# 10   41   blue-collar                unknown    unknown      no     no
# 11   25      services            high.school         no     yes     no
# ...

# %% [markdown]
# <h3>After applying the code, we've seen that instead of diverse values inside one column, the single column seems to have divided into two columns, each with its own set of values, which have been transformed from categorical values nominal scale to binary values.<h3/>
